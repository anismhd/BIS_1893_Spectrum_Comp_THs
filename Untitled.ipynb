# %%
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
files = glob.glob("AbaqusInpFiles/*.STA")

# %%
for file in files:
    with open(file) as f:
        print(file,f.readlines()[-1])
# Out:
# AbaqusInpFiles\RSN164.sta  THE ANALYSIS HAS COMPLETED SUCCESSFULLY
#
# AbaqusInpFiles\RSN286.sta    2  2518   1     0     0     0  0.000      7.30       0.002900
#
# AbaqusInpFiles\RSN289.sta    2  2382   1     0     0     0  0.000      5.72       0.002400
#
# AbaqusInpFiles\RSN290.sta    2  1897   1     0     0     0  0.000      5.50       0.002900
#
# AbaqusInpFiles\RSN3948.sta
# AbaqusInpFiles\RSN4013.sta  THE ANALYSIS HAS COMPLETED SUCCESSFULLY
#
# AbaqusInpFiles\RSN4841.sta  THE ANALYSIS HAS COMPLETED SUCCESSFULLY
#
# AbaqusInpFiles\RSN4843.sta  THE ANALYSIS HAS COMPLETED SUCCESSFULLY
#
# AbaqusInpFiles\RSN57.sta  THE ANALYSIS HAS COMPLETED SUCCESSFULLY
#
# AbaqusInpFiles\RSN70.sta  THE ANALYSIS HAS COMPLETED SUCCESSFULLY
#
# AbaqusInpFiles\RSN740.sta    2  2921   1     0     0     0  0.000      14.6       0.005000
#
# AbaqusInpFiles\RSN755.sta    2   687   1     0     0     0  0.000      3.43       0.005000
#
# AbaqusInpFiles\RSN78.sta
# AbaqusInpFiles\RSN827.sta
# ...

# %%
'AbaqusInpFiles\RSN164.odb'
'AbaqusInpFiles\RSN4013.odb'
'AbaqusInpFiles\RSN4841.odb'
'AbaqusInpFiles\RSN4843.odb'
'AbaqusInpFiles\RSN57.odb'
'AbaqusInpFiles\RSN70.odb'
'AbaqusInpFiles\RSN830.odb'
'AbaqusInpFiles\RSN88.odb'
